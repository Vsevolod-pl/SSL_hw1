# %%
import os
import json
import wandb
import torch
import numpy as np


from torch import nn
from torch.nn import functional as F
from torch import optim
from torch.utils.data import DataLoader, Dataset

from torchvision import models
from torchvision import transforms

from matplotlib import pyplot as plt
from tqdm.notebook import trange


from dataset import LabeledDataset, UnlabeledDataset

device = 'cuda' if torch.cuda.is_available else 'cpu'

# %%
normalization = transforms.Normalize([132., 126.4, 105.3], [67.8, 66.4, 70.5])

# %%
unldat = UnlabeledDataset('./data/', transform=normalization)
pretrain_loader = DataLoader(unldat, batch_size=10, shuffle=True, drop_last=True)

labdat = LabeledDataset('./data/train/labeled/', transform=normalization)
train_loader = DataLoader(labdat, batch_size=10, shuffle=True, drop_last=True)

# %%
model = models.resnet18(num_classes=10)

# %%
def forward_cut(X, model, level=-2):
    chs = list(model.children())[:level]
    res = X
    for ch in chs:
        X = res
        res = ch(X)
    return res

# %%
with open('versions.json', 'r') as f:
    versions = json.load(f)
versions['autoencoder-pretrain'] += 1
cur_ver = versions['autoencoder-pretrain']
with open('versions.json', 'w') as f:
    json.dump(versions, f)
    
wandb.init(project='Pretrain HW1', name=f'autoencoder-pretrain:{cur_ver}', notes='Denoising')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: vsevolodpl. Use `wandb login --relogin` to force relogin
# wandb version 0.13.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>C:\Users\vsevo\Desktop\vuz\SSL\HW1\wandb\run-20230201_151812-3h76ga7n</code>
# Syncing run <strong><a href="https://wandb.ai/vsevolodpl/Pretrain%20HW1/runs/3h76ga7n" target="_blank">autoencoder-pretrain:2</a></strong> to <a href="https://wandb.ai/vsevolodpl/Pretrain%20HW1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/vsevolodpl/Pretrain%20HW1/runs/3h76ga7n?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
def Upsample(in_channels, out_channels):
    return nn.Sequential(
        nn.LeakyReLU(),
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=4, stride=2),
        nn.BatchNorm2d(out_channels),
        nn.LeakyReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, padding=2),
        nn.BatchNorm2d(out_channels))

# %%
generator = nn.Sequential(
    Upsample(512, 256),
    Upsample(256, 128),
    Upsample(128, 64),
    Upsample(64, 32),
    Upsample(32, 3),
)

# %%
model.to(device)
generator.to(device)

opt = optim.Adam([*list(model.parameters()), *list(generator.parameters())])

# %%
X = next(iter(pretrain_loader))
X.shape
# Out:
# torch.Size([10, 3, 224, 224])

# %%
# model
with torch.no_grad():
    tmp = forward_cut(X.to(device), model, level=0)
    print(tmp.shape)
# Out:
# torch.Size([10, 3, 224, 224])

# %%
with torch.no_grad():
    tmp = forward_cut(X.to(device), model, level=-2)
    tmp = generator(tmp)
    print(tmp.shape)
# Out:
# torch.Size([10, 3, 224, 224])

# %%
stds = 1/torch.tensor([67.8, 66.4, 70.5])
means = -torch.tensor([132., 126.4, 105.3])*stds
denorm = transforms.Normalize(means, stds)
def to_img(X):
    with torch.no_grad():
        img = denorm(X)
    return img.transpose_(0,2).cpu()/255

# %%
noise = torch.randn_like(X)
plt.imshow(to_img((X*0.2+noise*0.8)[5]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# noise = torch.randn_like(X[0])
with torch.no_grad():
    dens = forward_cut(X*0.2+noise*0.8, model, -2)
    dens = generator(dens)
    plt.imshow(to_img(dens[5]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
epochs = 50

# %%
alpha = 0.5

# %%
for epoch in trange(epochs-2):
    opt.param_groups[0]['lr'] *= 0.97
    for X in pretrain_loader:
        opt.zero_grad()
        X = X.to(device)
        noise = torch.randn_like(X, device=device)
        
        hid = forward_cut(X+noise, model, -2)
        pred = generator(hid)
        
        loss = F.mse_loss(pred, X)
        
        loss.backward()
        opt.step()
        
        wandb.log({'loss':loss.item()})
    wandb.log({'lr':opt.param_groups[0]['lr']})
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9712/926619013.py in <module>
#      14         opt.step()
#      15
# ---> 16         wandb.log({'loss':loss.item()})
#      17     wandb.log({'lr':opt.param_groups[0]['lr']})
#
# KeyboardInterrupt:

# %%
#model.to(device)

final_opt = optim.Adam(model.parameters(), lr=5e-3)

# %%
for epoch in trange(50):
    final_opt.param_groups[0]['lr'] *= 0.96
    for X, y in train_loader:
        final_opt.zero_grad()
        X = X.to(device)
        y = y.to(device)
        
        pred = model(X)
        
        loss = F.cross_entropy(pred, y)
        
        loss.backward()
        final_opt.step()
        
        wandb.log({'final loss':loss.item()})
    wandb.log({'final lr':final_opt.param_groups[0]['lr']})

# %%
model = model.train(False)

# %%
infer_path, _, infer_files = next(os.walk('./data/test/'))

ans = []
classes_stat = []
for file in infer_files:
    filename = infer_path+'/'+file
    img = torch.tensor(plt.imread(filename), dtype=torch.float32)
    img = img.transpose_(0,2).unsqueeze(0)

    img = normalization(img)
    with torch.no_grad():
        class_idx = model(img.to(device)).argmax()
    classes_stat.append(class_idx.item())
    ans.append((file, labdat.classes[class_idx.item()]))

# %%
plt.hist(classes_stat, bins=10);

# %%
with open('./result_rotation-pretrain.csv', 'w') as f:
    print('id,class', file=f)
    for file, classn in ans:
        print(f'{file},{classn}', file=f)

# %%
labdat.classes
